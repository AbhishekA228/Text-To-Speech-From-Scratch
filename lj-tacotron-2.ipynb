# %% [markdown]
# Create file lists from train and validation sets

# %%
import pandas as pd

metadata = pd.read_csv(r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\LJSpeech-1.1\metadata.csv")
# Replace 'include_column' with the correct column name from your CSV file
metadata = metadata[:5]
print(metadata)

total = len(metadata)
split = 0.9
train = int(total * split)

train_metadata = metadata[:train]
val_metadata = metadata[train:]

with open(r'C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_train_filelist.txt', 'w') as f:
    for index,text in train_metadata.iterrows():
        filepath = r'C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\LJSpeech-1.1\wavs\%05d.wav' % index
        f.write(filepath + '|' + str(text) + '\n')

with open(r'C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_test_filelist.txt', 'w') as f:
    for index,text in val_metadata.iterrows():
        filepath = r'C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\LJSpeech-1.1\wavs\%05d.wav' % index
        f.write(filepath + '|' + str(text) + '\n')
# Out:
#                                  LJ001-0001|Printing  \
# 0  LJ001-0002|in being comparatively modern.|in b...
# 1  LJ001-0003|For although the Chinese took impre...
# 2                LJ001-0004|produced the block books
# 3  LJ001-0005|the invention of movable metal lett...
# 4  LJ001-0006|And it is worth mention in passing ...
#
#    in the only sense with which we are at present concerned  \
# 0                                                NaN
# 1   by a similar process|For although the Chinese...
# 2   which were the immediate predecessors of the ...
# 3                                                NaN
# 4                   as an example of fine typography
#
#    differs from most if not from all the arts and crafts represented in the Exhibition|Printing  \
# 0                                                NaN
# 1                               by a similar process
# 2                          |produced the block books
# 3                                                NaN
# 4           |And it is worth mention in passing that
#
#    in the only sense with which we are at present concerned.1  \
# 0                                                NaN
# 1                                                NaN
# 2   which were the immediate predecessors of the ...
# 3                                                NaN
# 4                   as an example of fine typography
#
#    differs from most if not from all the arts and crafts represented in the Exhibition  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0        NaN        NaN        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN        NaN        NaN         NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
df = pd.read_csv(r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_train_filelist.txt", sep="|", names=["path", "text"])

# %% [markdown]
# Install dependencies

# %%
with open(r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_train_filelist.txt", "r") as f:
    lines = f.readlines()
with open(r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_train_filelist.txt", "w") as f:
    for line in lines:
        line = line.replace('DUMMY', '/kaggle/input/the-lj-speech-dataset/LJSpeech-1.1/wavs')
        f.write(line)

# %%
# with open("/kaggle/working/tacotron2/filelists/ljs_audio_text_train_filelist.txt", "r") as f:
#     lines = f.readlines()
# lines

# %%
with open(r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_test_filelist.txt", "r") as f:
    lines = f.readlines()
with open(r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_test_filelist.txt", "w") as f:
    for line in lines:
        line = line.replace('DUMMY', '/kaggle/input/the-lj-speech-dataset/LJSpeech-1.1/wavs')
        f.write(line)

# %%
# !mv r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_train_filelist.txt"
# Out:
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !mv r"C:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\tacotron2-master\filelists\ljs_audio_text_test_filelist.txt"
# Out:
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !ls tacotron2/filelists
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install tensorflow==1.15
# !pip install unidecode
# !pip install inflect
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.15 (from versions: 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.11.1, 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1)
# ERROR: No matching distribution found for tensorflow==1.15
# Requirement already satisfied: unidecode in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.3.8)
# Requirement already satisfied: inflect in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (7.0.0)
# Requirement already satisfied: pydantic>=1.9.1 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from inflect) (2.6.4)
# Requirement already satisfied: typing-extensions in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from inflect) (4.10.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pydantic>=1.9.1->inflect) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pydantic>=1.9.1->inflect) (2.16.3)

# %% [markdown]
# Download pretrained model from Google Drive for transfer learning

# %%
# !python --version
# Out:
# Python 3.9.13

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1c5ZTuT7J08wLUoVZ2KkUs_VdZuJ86ZqA
# Out:
# Requirement already satisfied: gdown in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]->gdown) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\abhishek a\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tqdm->gdown) (0.4.6)
# Downloading...
# From (original): https://drive.google.com/uc?id=1c5ZTuT7J08wLUoVZ2KkUs_VdZuJ86ZqA
# From (redirected): https://drive.google.com/uc?id=1c5ZTuT7J08wLUoVZ2KkUs_VdZuJ86ZqA&confirm=t&uuid=80b41906-77a7-4e1b-b19a-bc5f9cb96146
# To: c:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch
#  75%|███████▍  | 84.4M/113M [00:10<00:08, 3.33MB/s]
#  75%|███████▌  | 84.9M/113M [00:11<00:13, 2.09MB/s]
#  76%|███████▌  | 86.0M/113M [00:11<00:11, 2.41MB/s]
#  77%|███████▋  | 86.5M/113M [00:11<00:09, 2.68MB/s]
#  78%|███████▊  | 87.6M/113M [00:11<00:07, 3.59MB/s]
#  79%|███████▉  | 89.1M/113M [00:11<00:04, 5.28MB/s]
#  80%|███████▉  | 90.2M/113M [00:11<00:03, 5.93MB/s]
#  81%|████████▏ | 91.8M/113M [00:12<00:03, 6.59MB/s]
#  82%|████████▏ | 92.8M/113M [00:13<00:08, 2.30MB/s]
#  83%|████████▎ | 93.8M/113M [00:13<00:07, 2.37MB/s]
#  84%|████████▎ | 94.4M/113M [00:13<00:07, 2.61MB/s]
#  85%|████████▍ | 95.4M/113M [00:14<00:05, 3.16MB/s]
#  85%|████████▌ | 95.9M/113M [00:14<00:09, 1.80MB/s]
#  86%|████████▌ | 96.5M/113M [00:15<00:12, 1.34MB/s]
#  86%|████████▋ | 97.5M/113M [00:15<00:08, 1.74MB/s]
#  87%|████████▋ | 98.0M/113M [00:16<00:08, 1.83MB/s]
#  87%|████████▋ | 98.6M/113M [00:16<00:07, 1.81MB/s]
#  88%|████████▊ | 99.6M/113M [00:16<00:05, 2.24MB/s]
#  89%|████████▉ | 100M/113M [00:16<00:05, 2.29MB/s]
#  89%|████████▉ | 101M/113M [00:17<00:08, 1.49MB/s]
#  90%|████████▉ | 101M/113M [00:17<00:06, 1.83MB/s]
#  91%|█████████ | 102M/113M [00:17<00:03, 2.68MB/s]
#  91%|█████████ | 103M/113M [00:18<00:03, 2.77MB/s]
#  92%|█████████▏| 103M/113M [00:18<00:03, 3.01MB/s]
#  92%|█████████▏| 104M/113M [00:18<00:03, 3.00MB/s]
#  93%|█████████▎| 105M/113M [00:19<00:04, 1.60MB/s]
#  93%|█████████▎| 105M/113M [00:19<00:04, 1.66MB/s]
#  94%|█████████▍| 106M/113M [00:19<00:03, 1.88MB/s]
#  95%|█████████▍| 107M/113M [00:20<00:03, 1.76MB/s]
#  95%|█████████▌| 107M/113M [00:21<00:04, 1.33MB/s]
#  96%|█████████▌| 108M/113M [00:21<00:03, 1.59MB/s]
#  96%|█████████▌| 109M/113M [00:21<00:03, 1.38MB/s]
#  97%|█████████▋| 109M/113M [00:22<00:03, 1.24MB/s]
#  97%|█████████▋| 110M/113M [00:22<00:02, 1.40MB/s]
#  98%|█████████▊| 111M/113M [00:22<00:01, 2.18MB/s]
#  99%|█████████▉| 112M/113M [00:23<00:00, 2.80MB/s]
# 100%|█████████▉| 113M/113M [00:23<00:00, 3.64MB/s]
# 100%|██████████| 113M/113M [00:23<00:00, 4.86MB/s]

# %% [markdown]
# Train the model for 1000 epochs with a batch size of 32

# %%
# !apt-get update --fix-missing
# !apt-get install sox -y
# !soxi /kaggle/input/the-lj-speech-dataset/LJSpeech-1.1/wavs/LJ001-0001.wav
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'soxi' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !python train.py --output_directory=outdir --log_directory=logdir -c tacotron2_statedict.pt --warm_start
# !python train.py --output_directory=outdir --log_directory=logdir -c tacotron2_statedict.pt --warm_start --hparams sampling_rate=22050,iters_per_checkpoint=100
# Out:
# Traceback (most recent call last):
#   File "c:\Users\Abhishek A\Desktop\AI&ML\NLP Projects\Text To Speech From Scratch\train.py", line 8, in <module>
#     from distributed import apply_gradient_allreduce
# ModuleNotFoundError: No module named 'distributed'

# %% [markdown]
# ## Inference
# ### Synthesize generated audio samples from text

# %%
# !python -m pip install spacy

# %%
#Trying Inflect 5.0.x series
# !pip install inflect==5.0.1
# Out:
# Collecting inflect==5.0.1
#   Downloading inflect-5.0.1-py3-none-any.whl (31 kB)
# Installing collected packages: inflect
#   Attempting uninstall: inflect
#     Found existing installation: inflect 6.0.4
#     Uninstalling inflect-6.0.4:
#       Successfully uninstalled inflect-6.0.4
# Successfully installed inflect-5.0.1

# %%
from multiprocessing import Pool
import matplotlib.pylab as plt
# %matplotlib inline
from tqdm.notebook import tqdm
import IPython.display as ipd
from time import time, sleep
import scipy.io.wavfile
import numpy as np
import matplotlib
import torch
import sys

sys.path.append('waveglow/')

from audio_processing import griffin_lim
from layers import TacotronSTFT, STFT
from hparams import create_hparams
from text import text_to_sequence
from denoiser import Denoiser
from train import load_model
from model import Tacotron2

# %%
def plot_data(data, figsize=(16, 4)):
    fig, axes = plt.subplots(1, len(data), figsize=figsize)
    for i in range(len(data)):
        axes[i].imshow(data[i], aspect='auto', origin='lower', interpolation='none')

# %%
hparams = create_hparams()
hparams.sampling_rate = 22050

# %%
# checkpoint = int(input("Enter steps at latest checkpoint: "))
checkpoint_path = f"outdir/checkpoint_900"
# checkpoint_path = "/kaggle/working/tacotron2/tacotron2_statedict.pt"
model = load_model(hparams)
model.load_state_dict(torch.load(checkpoint_path)['state_dict'])
_ = model.cuda().eval().half()

# %%
# !gdown https://drive.google.com/uc?id=1rpK8CzAAirq9sWZhe9nlfvxMF1dRgFbF
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1rpK8CzAAirq9sWZhe9nlfvxMF1dRgFbF
# From (redirected): https://drive.google.com/uc?id=1rpK8CzAAirq9sWZhe9nlfvxMF1dRgFbF&confirm=t&uuid=5b9cfeea-1775-4013-9c97-9872d832bda2
# To: /kaggle/working/tacotron2/waveglow_256channels_universal_v5.pt
# 100%|████████████████████████████████████████| 676M/676M [00:17<00:00, 38.4MB/s]

# %%
waveglow_path = 'waveglow_256channels_universal_v5.pt'
waveglow = torch.load(waveglow_path)['model']
waveglow.cuda().eval().half()
for k in waveglow.convinv:
    k.float()
denoiser = Denoiser(waveglow)
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.conv.ConvTranspose1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.container.ModuleList' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)
# /opt/conda/lib/python3.7/site-packages/torch/serialization.py:658: SourceChangeWarning: source code of class 'torch.nn.modules.conv.Conv1d' has changed. you can retrieve the original source code by accessing the object's source attribute or set `torch.nn.Module.dump_patches = True` and use the patch tool to revert the changes.
#   warnings.warn(msg, SourceChangeWarning)

# %%
def synthesize(word, n=5, cleaners=['english_cleaners'], sigma=0.666, strength=0.01):
    sequence = np.array(text_to_sequence(word, cleaners))[None, :]
    sequence = torch.autograd.Variable(torch.from_numpy(sequence)).cuda().long()
    with torch.no_grad():
        mel_outputs, mel_outputs_postnet, _, alignments = model.inference(sequence)
    audio = waveglow.infer(mel_outputs_postnet, sigma=sigma)
    audio_denoised = denoiser(audio, strength=strength)[:, 0]
    audio = audio[0].data.cpu().numpy().tolist()
    mel_outputs = mel_outputs.float().data.cpu().numpy()[0]
    mel_outputs_postnet = mel_outputs_postnet.float().data.cpu().numpy()[0]
    alignments = alignments.float().data.cpu().numpy()[0]
    return audio, mel_outputs, mel_outputs_postnet, alignments

# %%
tests = [
         "Scientists at the CERN laboratory say they have discovered a new particle.",
#          "The state of Florida reports a surge in coronavirus deaths as restrictions are upended.",
#          "How much wood would a woodchuck chuck if a woodchuck could chuck wood?",
#          "A woodchuck would chuck all the wood it could chuck if a woodchuck could chuck wood.",
#          "Peter Piper picked a peck of pickled peppers. How many pickled peppers did Peter Piper pick?",
#          "Sally sells seashells by the seashore. The shells she sells are seashells I'm sure.",
#          "The blue lagoon is a nineteen eighty American romance adventure film.",
#          "George Washington was the first President of the United States.",
#          "Basilar membrane and otolaryngology are not auto-correlations.",
#          "Biden holds first foreign meeting with Canada's Justin Trudeau."
]

# %%
for text in tests:
    audio, mel_outputs, mel_outputs_postnet, alignments = synthesize(text, n=15)
    ipd.display_html(ipd.HTML(f"""
    <h3>{text}</h3>
    <br/>
    """))
    ipd.display(ipd.Audio(data = audio, rate = 22050, autoplay = False))
# Out:
#     <h3>Scientists at the CERN laboratory say they have discovered a new particle.</h3>
#     <br/>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
